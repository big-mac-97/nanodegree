# %%
CRISP-DM

Business Understanding: Airbnb is a company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. They provide a fantastic services to many travelers and hosts alike, but are frequently criticised for their role in housing affordability. The argument is that many property investors prefer to generate income from their portfolio (big or small) via Airbnb instead of traditional rental leases. This reduces supply of housing for locals and supposedly results in an increase in not only rent but property prices in general as a greater proportion of the market is overtaken, at higher prices, by Airbnb investor-operators.

Can we use the publicly-available Airbnb data to make any inferences about the Boston and Seattle housing markets?
Look at proportion of time listed vs housing availability?
Look at zip code and time occupied?
Correlation between zip code and number of bedrooms and density of listings?

Data Understanding: 

    
    
import pandas as pd
from datetime import date, timedelta
import matplotlib.pyplot as plt

folder_path = "C:\Users\EMCINDOE\nanodegree\Project 1\"
    
seattle_calendar_df=pd.read_csv(folder_path + "seattle_calendar.csv")
seattle_listings_df=pd.read_csv(folder_path + "seattle_listings.csv")
seattle_reviews_df=pd.read_csv(folder_path + "seattle_reviews.csv")

boston_calendar_df=pd.read_csv(folder_path + "boston_calendar.csv")
boston_listings_df=pd.read_csv(folder_path + "boston_listings.csv")
boston_reviews_df=pd.read_csv(folder_path + "boston_reviews.csv")

seattle_calendar_df['date']=pd.to_datetime(seattle_calendar_df['date'])
boston_calendar_df['date']=pd.to_datetime(boston_calendar_df['date'])



daily_availability = []
dates = []
for i in seattle_calendar_df['date'].drop_duplicates():
    dates.append(i)
    daily_availability.append((seattle_calendar_df[seattle_calendar_df['date']==i]['available']=='t').mean())

plt.plot(dates,daily_availability)

d = {'dates':dates,'daily_availability':daily_availability}
daily_df = pd.DataFrame(d)

pd.set_option("display.max_rows", None)
daily_df



def listing_availability(calendar_df,listing_id):
    df = calendar_df[calendar_df['listing_id']==listing_id]
    return (df['available']=='t').mean()





import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
pd.options.mode.chained_assignment = None #fixing a false-positive chained index warning

boston_calendar_df=pd.read_csv("W:\\CHPP\\CHPP METALLURGY\\1.0 Preparation Plant\\1.0 Personal Folders\\EMcIndoe\\Data Literacy\\Nanodegree\\Project 1\\boston_calendar.csv")
boston_listings_df=pd.read_csv("W:\\CHPP\\CHPP METALLURGY\\1.0 Preparation Plant\\1.0 Personal Folders\\EMcIndoe\\Data Literacy\\Nanodegree\\Project 1\\boston_listings.csv")
boston_reviews_df=pd.read_csv("W:\\CHPP\\CHPP METALLURGY\\1.0 Preparation Plant\\1.0 Personal Folders\\EMcIndoe\\Data Literacy\\Nanodegree\\Project 1\\boston_reviews.csv")

list(df.columns)
df.groupby('host_neighbourhood')['review_scores_rating'].mean().sort_values(ascending=False)

#source page: https://stackoverflow.com/questions/45685726/python-scatter-plot-over-background-image-for-data-verification?noredirect=1&lq=1

df['review_scores_value_ranked'] = df['review_scores_value'].rank()

df.plot.scatter('longitude','latitude',c='review_scores_value_ranked',cmap = 'hot',zorder=1,s=10)
img = plt.imread("W:\\CHPP\\CHPP METALLURGY\\1.0 Preparation Plant\\1.0 Personal Folders\\EMcIndoe\\Data Literacy\\Nanodegree\\Project 1\\boston_image.png")

ext = [df['longitude'].min(), df['longitude'].max(), df['latitude'].min(), df['latitude'].max()]
plt.imshow(img, zorder=0, extent=ext)

aspect=img.shape[0]/float(img.shape[1])*((ext[1]-ext[0])/(ext[3]-ext[2]))
plt.gca().set_aspect(aspect)
plt.xticks(rotation = 45)
plt.show()


mofab_cluster_df = df[(df['latitude'] > 42.342) & (df['latitude'] < 42.346) & (df['longitude'] > -71.104) & (df['longitude'] < -71.096)]
mofab_cluster_df['price']= pd.to_numeric(mofab_cluster_df['price'].str.slice(start=1))
mofab_cluster_df.hist('price',bins = 20)

mofab_cluster_df.plot.scatter('price','review_scores_value')

mofab_cluster_df.plot.scatter('longitude','latitude',c='review_scores_value',cmap = 'hot',zorder=1,s=10)
img = plt.imread("W:\\CHPP\\CHPP METALLURGY\\1.0 Preparation Plant\\1.0 Personal Folders\\EMcIndoe\\Data Literacy\\Nanodegree\\Project 1\\boston_image.png")

ext = [df['longitude'].min(), df['longitude'].max(), df['latitude'].min(), df['latitude'].max()]
plt.imshow(img, zorder=0, extent=ext)

aspect=img.shape[0]/float(img.shape[1])*((ext[1]-ext[0])/(ext[3]-ext[2]))
plt.gca().set_aspect(aspect)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# CRISP-DM
#
# Business Understanding: Airbnb is a company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. They provide a fantastic services to many travelers and hosts alike, but are frequently criticised for their role in housing affordability. The argument is that many property investors prefer to generate income from their portfolio (big or small) via Airbnb instead of traditional rental leases. This reduces supply of housing for locals and supposedly results in an increase in not only rent but property prices in general as a greater proportion of the market is overtaken, at higher prices, by Airbnb investor-operators.
#
# Can we use the publicly-available Airbnb data to make any inferences about the Boston and Seattle housing markets?
# Look at proportion of time listed vs housing availability?
# Look at zip code and time occupied?
# Correlation between zip code and number of bedrooms and density of listings?
#
# Data Understanding:

# %%
#Import relevant Python packages for the analysis and plotting of the datasets
import pandas as pd
from datetime import date, timedelta
import matplotlib.pyplot as plt

#Define folder path of data file location
folder_path = "C:\\Users\\EMCINDOE\\nanodegree\\Project 1\\"

#Import Airbnb data files for Seattle and Boston
seattle_calendar_df=pd.read_csv(folder_path + "seattle_calendar.csv")
seattle_listings_df=pd.read_csv(folder_path + "seattle_listings.csv")
seattle_reviews_df=pd.read_csv(folder_path + "seattle_reviews.csv")

boston_calendar_df=pd.read_csv(folder_path + "boston_calendar.csv")
boston_listings_df=pd.read_csv(folder_path + "boston_listings.csv")
boston_reviews_df=pd.read_csv(folder_path + "boston_reviews.csv")

#Convert 
#seattle_calendar_df['date']=pd.to_datetime(seattle_calendar_df['date'])
#boston_calendar_df['date']=pd.to_datetime(boston_calendar_df['date'])

# %%
pd.to_datetime(seattle_calendar_df['date']).dt.strftime('%Y-%m-%d')
# Out:
# 0          2016-01-04
# 1          2016-01-05
# 2          2016-01-06
# 3          2016-01-07
# 4          2016-01-08
#               ...
# 1393565    2016-12-29
# 1393566    2016-12-30
# 1393567    2016-12-31
# 1393568    2017-01-01
# 1393569    2017-01-02
# Name: date, Length: 1393570, dtype: object
